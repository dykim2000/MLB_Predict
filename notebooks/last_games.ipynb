# %% [markdown]
# ## Scraping Last 7 Games (%) and Win/Lose Streaks
# Source : https://www.baseball-reference.com/boxes/

# %%
import pandas as pd

# %%
game_logs = pd.read_csv("../data/game_logs_2024.csv")

# %%
games["game_datetime"] = pd.to_datetime(games["game_datetime"])

# %% [markdown]
# Retreiving game results from the <b> Original </b> dataset, dividing each match by home and away game

# %%
games["home_win"] = (games["home_score"] > games["away_score"]).astype(int)
games["away_win"] = (games["away_score"] > games["home_score"]).astype(int)

home_df = games[["game_id", "game_datetime", "home_name", "home_win"]].rename(
    columns={"home_name": "team", "home_win": "result", "game_datetime": "date"}
)
away_df = games[["game_id", "game_datetime", "away_name", "away_win"]].rename(
    columns={"away_name": "team", "away_win": "result", "game_datetime": "date"}
)

df = pd.concat([home_df, away_df], ignore_index=True)

# %%
df = pd.concat([home_df, away_df], ignore_index=True)

# %%
df = df.sort_values(["team", "date"]).reset_index(drop=True)

# %% [markdown]
# Rolling up the 7 matches to calculate the "Last 7 win percentage"

# %%
df["last_7win_pct"] = None
for team, group in df.groupby("team"):
    shifted = group["result"].shift()
    win_pct = shifted.rolling(window=7).mean()
    df.loc[group.index, "last_7win_pct"] = win_pct

# %%
df.head(20)
# Out:
#     game_id                      date                       team  result  \
# 0    747298 2024-07-17 00:00:00+00:00  American League All-Stars       1
# 1    748264 2024-02-23 20:10:00+00:00       Arizona Diamondbacks       0
# 2    748250 2024-02-24 20:10:00+00:00       Arizona Diamondbacks       1
# 3    748229 2024-02-25 20:10:00+00:00       Arizona Diamondbacks       1
# 4    748219 2024-02-26 20:05:00+00:00       Arizona Diamondbacks       0
# 5    748200 2024-02-27 20:10:00+00:00       Arizona Diamondbacks       0
# 6    748188 2024-02-28 20:05:00+00:00       Arizona Diamondbacks       1
# 7    748168 2024-02-29 20:10:00+00:00       Arizona Diamondbacks       1
# 8    748156 2024-03-02 01:05:00+00:00       Arizona Diamondbacks       1
# 9    748142 2024-03-02 20:10:00+00:00       Arizona Diamondbacks       0
# 10   748119 2024-03-03 20:10:00+00:00       Arizona Diamondbacks       0
# 11   748109 2024-03-04 20:05:00+00:00       Arizona Diamondbacks       0
# 12   748094 2024-03-05 20:10:00+00:00       Arizona Diamondbacks       1
# 13   748074 2024-03-07 20:05:00+00:00       Arizona Diamondbacks       0
# 14   748062 2024-03-08 20:10:00+00:00       Arizona Diamondbacks       1
# 15   748043 2024-03-09 20:05:00+00:00       Arizona Diamondbacks       0
# 16   748042 2024-03-09 20:10:00+00:00       Arizona Diamondbacks       0
# 17   748027 2024-03-10 20:05:00+00:00       Arizona Diamondbacks       0
# 18   748012 2024-03-11 20:10:00+00:00       Arizona Diamondbacks       0
# 19   747999 2024-03-12 20:10:00+00:00       Arizona Diamondbacks       0
#
#    last_7win_pct
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8       0.571429
# 9       0.714286
# 10      0.571429
# 11      0.428571
# 12      0.428571
# 13      0.571429
# 14      0.428571
# 15      0.428571
# 16      0.285714
# 17      0.285714
# 18      0.285714
# 19      0.285714

# %% [markdown]
# ### Retrieving the Streak Part
#
# 7 win streak : +7 <br/>
# 5 lose streak : -5

# %%
def compute_streak(results):
    streaks = []
    streak = 0
    for result in results:
        if result == 1: 
            streak = streak + 1 if streak > 0 else 1
        else:
            streak = streak - 1 if streak < 0 else -1
        streaks.append(streak)
    return streaks

# %%
df["streak"] = None
for team,group in df.groupby("team"):
    streaks = compute_streak(group["result"].tolist())
    df.loc[group.index, "streak"] = streaks

# %%
df
# Out:
#       game_id                      date                            team  \
# 0      747298 2024-07-17 00:00:00+00:00       American League All-Stars
# 1      748264 2024-02-23 20:10:00+00:00            Arizona Diamondbacks
# 2      748250 2024-02-24 20:10:00+00:00            Arizona Diamondbacks
# 3      748229 2024-02-25 20:10:00+00:00            Arizona Diamondbacks
# 4      748219 2024-02-26 20:05:00+00:00            Arizona Diamondbacks
# ...       ...                       ...                             ...
# 5991   744796 2024-09-26 17:05:00+00:00            Washington Nationals
# 5992   744797 2024-09-27 22:45:00+00:00            Washington Nationals
# 5993   744799 2024-09-28 20:05:00+00:00            Washington Nationals
# 5994   744798 2024-09-29 19:05:00+00:00            Washington Nationals
# 5995   761424 2024-03-26 16:05:00+00:00  Washington Nationals Prospects
#
#       result last_7win_pct streak
# 0          1           NaN      1
# 1          0           NaN     -1
# 2          1           NaN      1
# 3          1           NaN      2
# 4          0           NaN     -1
# ...      ...           ...    ...
# 5991       0      0.142857     -4
# 5992       1      0.142857      1
# 5993       1      0.285714      2
# 5994       0      0.428571     -1
# 5995       0           NaN     -1
#
# [5996 rows x 6 columns]

# %%
df = df.drop_duplicates(subset=["game_id", "team"])

home = df.rename(columns={
    "last_7win_pct": "home_last7_win_pct",
    "streak": "home_streak"})[["game_id", "team", "home_last7_win_pct", "home_streak"]]

away = df.rename(columns={
    "last_7win_pct": "away_last7_win_pct",
    "streak": "away_streak"})[["game_id", "team", "away_last7_win_pct", "away_streak"]]

# %%
final_df = pd.read_csv("../data/final_game_logs.csv")

# %%
df["game_id"].value_counts().value_counts()
# Out:
# count
# 2    2959
# Name: count, dtype: int64

# %%
final_df = final_df.merge(
    home, 
    left_on=["game_id", "home_name"], 
    right_on=["game_id", "team"], 
    how="left"
).drop(columns=["team"])

final_df = final_df.merge(
    away, 
    left_on=["game_id", "away_name"], 
    right_on=["game_id", "team"], 
    how="left"
).drop(columns=["team"])

# %%
final_df
# Out:
#       Unnamed: 0  game_id            home_name             away_name  \
# 0              0   748266     San Diego Padres   Los Angeles Dodgers
# 1              1   748344       Boston Red Sox  Northeastern Huskies
# 2              2   748263        Texas Rangers    Kansas City Royals
# 3              3   748341         Chicago Cubs     Chicago White Sox
# 4              4   748260  Los Angeles Dodgers      San Diego Padres
# ...          ...      ...                  ...                   ...
# 3639        3075   775300  Los Angeles Dodgers      New York Yankees
# 3640        3076   775294  Los Angeles Dodgers      New York Yankees
# 3641        3077   775298     New York Yankees   Los Angeles Dodgers
# 3642        3078   775297     New York Yankees   Los Angeles Dodgers
# 3643        3079   775296     New York Yankees   Los Angeles Dodgers
#
#      home_probable_pitcher away_probable_pitcher  away_score  home_score  \
# 0             Joe Musgrove           Gavin Stone          14           1
# 1         Helcris Olivárez          Aiven Cabral           2           7
# 2             Dane Dunning       Daniel Lynch IV           4           5
# 3             Jordan Wicks          Jesse Chavez           1           8
# 4             Landon Knack           Jhony Brito           1           4
# ...                    ...                   ...         ...         ...
# 3639         Jack Flaherty           Gerrit Cole           3           6
# 3640    Yoshinobu Yamamoto          Carlos Rodón           2           4
# 3641        Clarke Schmidt        Walker Buehler           4           2
# 3642              Luis Gil         Ben Casparius           4          11
# 3643           Gerrit Cole         Jack Flaherty           7           6
#
#       home_ERA  home_ER  ...  wind  condition_code  home_lineup_score  \
# 0         3.88     43.0  ...   3.0               2           0.614000
# 1          NaN      NaN  ...  16.0               0           0.951000
# 2         5.31     56.0  ...   9.0               0           0.648111
# 3         5.48     28.0  ...   6.0               3           0.666556
# 4         3.65     28.0  ...   5.0               3           0.962647
# ...        ...      ...  ...   ...             ...                ...
# 3639      3.17     57.0  ...   5.0               1           0.764100
# 3640      3.00     30.0  ...   5.0               0           0.754400
# 3641      2.85     27.0  ...   5.0               1           0.693500
# 3642      3.50     59.0  ...  10.0               3           0.743667
# 3643      3.41     36.0  ...   5.0               0           0.758222
#
#       away_lineup_score  home_n_starters  away_n_starters  home_last7_win_pct  \
# 0              0.833250               19               20                 NaN
# 1              0.453722               17               18                 NaN
# 2              0.583333               18               18                 NaN
# 3              0.287000               18               18                 NaN
# 4              0.271895               17               19                 NaN
# ...                 ...              ...              ...                 ...
# 3639           0.692273               10               11            0.714286
# 3640           0.733273               10               11            0.714286
# 3641           0.763900               10               10            0.571429
# 3642           0.757300                9               10            0.428571
# 3643           0.743300                9               10            0.428571
#
#       home_streak  away_last7_win_pct  away_streak
# 0              -1                 NaN            1
# 1               1                 NaN           -1
# 2               1                 NaN           -1
# 3               1                 NaN           -1
# 4               2                 NaN           -2
# ...           ...                 ...          ...
# 3639            2            0.857143           -1
# 3640            3            0.714286           -2
# 3641           -3            0.714286            4
# 3642            1            0.857143           -1
# 3643           -1            0.714286            1
#
# [3644 rows x 48 columns]

# %%
final_df.to_csv("../data/final_game_logs.csv")
