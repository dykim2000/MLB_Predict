# %% [markdown]
# ## One-Hot encoding the Weather Condition Column

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/final_game_logs.csv")

# %%
df["condition_code"] = df["condition_code"].astype("category")
condition_dummies = pd.get_dummies(df["condition_code"], prefix="condition")

# %%
df = pd.concat([df, condition_dummies], axis=1)
df = df.drop(columns=["condition_code"])

# %%
df = df.drop(columns=["Unnamed: 0.1", "Unnamed: 0"])

# %%
df.head()
# Out:
#    game_id            home_name             away_name home_probable_pitcher  \
# 0   748266     San Diego Padres   Los Angeles Dodgers          Joe Musgrove
# 1   748344       Boston Red Sox  Northeastern Huskies      Helcris Olivárez
# 2   748263        Texas Rangers    Kansas City Royals          Dane Dunning
# 3   748341         Chicago Cubs     Chicago White Sox          Jordan Wicks
# 4   748260  Los Angeles Dodgers      San Diego Padres          Landon Knack
#
#   away_probable_pitcher  away_score  home_score  home_ERA  home_ER  home_R  \
# 0           Gavin Stone          14           1      3.88     43.0    44.0
# 1          Aiven Cabral           2           7       NaN      NaN     NaN
# 2       Daniel Lynch IV           4           5      5.31     56.0    60.0
# 3          Jesse Chavez           1           8      5.48     28.0    31.0
# 4           Jhony Brito           1           4      3.65     28.0    28.0
#
#    ...  condition_0  condition_1  condition_2  condition_3  condition_4  \
# 0  ...        False        False         True        False        False
# 1  ...         True        False        False        False        False
# 2  ...         True        False        False        False        False
# 3  ...        False        False        False         True        False
# 4  ...        False        False        False         True        False
#
#    condition_5  condition_6  condition_7  condition_8  condition_9
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
# [5 rows x 56 columns]

# %%
df.to_csv("../data/final_game_logs.csv", index=False)
